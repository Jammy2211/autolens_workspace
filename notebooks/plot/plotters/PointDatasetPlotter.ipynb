# %% [markdown]
# Plots: PointDatasetPlotter
# ==========================
#
# This example illustrates how to plot a `PointDataset` dataset using an `PointDatasetPlotter`.

# %%
# %matplotlib inline
from pyprojroot import here
workspace_path = str(here())
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

from os import path
import autolens as al
import autolens.plot as aplt
# Out:
# /mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace
# Working Directory has been set to `/mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace`
# WARNING:autoconf.conf:Pushing new config with path /mnt/c/Users/Jammy/Code/PyAuto/PyAutoArray/autoarray/config
# 2021-06-09 15:56:00,734 - autoconf.conf - WARNING - Pushing new config with path /mnt/c/Users/Jammy/Code/PyAuto/PyAutoFit/autofit/config
# 2021-06-09 15:56:00,979 - autoconf.conf - WARNING - Pushing new config with path /mnt/c/Users/Jammy/Code/PyAuto/PyAutoGalaxy/autogalaxy/config
# 2021-06-09 15:56:01,215 - autoconf.conf - WARNING - Pushing new config with path /mnt/c/Users/Jammy/Code/PyAuto/PyAutoLens/autolens/config

# %% [markdown]
# First, lets load an example strong lens `PointDataset` object.

# %%
dataset_name = "mass_sie__source_point__0"
dataset_path = path.join("dataset", "point_source", dataset_name)

point_dict = al.PointDict.from_json(
    file_path=path.join(dataset_path, "point_dict.json")
)

point_dataset = point_dict["point_0"]

# %% [markdown]
# We now pass the point dataset to an `PointDatasetPlotter` and call various `figure_*` methods to plot different
# attributes.

# %%
point_dataset_plotter = aplt.PointDatasetPlotter(point_dataset=point_dataset)
point_dataset_plotter.figures_2d(
    positions=True, fluxes=True
)

# %% [markdown]
# Finish.
