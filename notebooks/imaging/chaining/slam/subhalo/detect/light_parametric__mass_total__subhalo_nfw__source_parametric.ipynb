# %% [markdown]
# SLaM (Source, Light and Mass): Light Parametric + Mass Total + Subhalo NFW + Source Parametric
# ==============================================================================================
#
# SLaM pipelines break the analysis down into multiple pipelines which focus on modeling a specific aspect of the strong
# lens, first the Source, then the (lens) Light and finally the Mass. Each of these pipelines has it own inputs which
# which customize the model and analysis in that pipeline.
#
# The models fitted in earlier pipelines determine the model used in later pipelines. For example, if the SOURCE PIPELINE
# uses a parametric `EllSersic` profile for the bulge, this will be used in the subsequent MASS TOTAL PIPELINE.
#
# Using a SOURCE PARAMETRIC PIPELINE, LIGHT PARAMETRIC PIPELINE, MASS TOTAL PIPELINE and SUBHALO PIPELINE this SLaM script
# fits `Imaging` of a strong lens system, where in the final model:
#
#  - The lens galaxy's light is a bulge+disk `EllSersic` and `EllExponential`.
#  - The lens galaxy's total mass distribution is an `EllIsothermal`.
#  - A dark matter subhalo near The lens galaxy mass is included as a`SphNFWMCRLudLow`.
#  - The source galaxy is an `EllSersic`.
#
# This uses the SLaM pipelines:
#
#  `source_parametric/with_lens_light`
#  `light_parametric/with_lens_light`
#  `mass_total/with_lens_light`
#  `subhalo/detection_single_plane`
#
# Check them out for a full description of the analysis!

# %%
# %matplotlib inline
from pyprojroot import here
workspace_path = str(here())
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

import os
import sys
from os import path
import autofit as af
import autolens as al
import autolens.plot as aplt

sys.path.insert(0, os.getcwd())
import slam
# Out:
# /mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace
# Working Directory has been set to `/mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace`

# %% [markdown]
# __Dataset + Masking__
#
# Load, plot and mask the `Imaging` data.

# %%
dataset_name = "light_sersic_exp__mass_sie__subhalo_nfw__source_sersic"
dataset_path = path.join("dataset", "imaging", "subhalo", dataset_name)

imaging = al.Imaging.from_fits(
    image_path=path.join(dataset_path, "image.fits"),
    noise_map_path=path.join(dataset_path, "noise_map.fits"),
    psf_path=path.join(dataset_path, "psf.fits"),
    pixel_scales=0.05,
)

mask = al.Mask2D.circular(
    shape_native=imaging.shape_native, pixel_scales=imaging.pixel_scales, radius=3.0
)

imaging = imaging.apply_mask(mask=mask)

imaging_plotter = aplt.ImagingPlotter(imaging=imaging)
imaging_plotter.subplot_imaging()

# %% [markdown]
# __Settings AutoFit__
#
# The settings of autofit, which controls the output paths, parallelization, database use, etc.

# %%
settings_autofit = slam.SettingsAutoFit(
    path_prefix=path.join("imaging", "slam"),
    unique_tag=dataset_name,
    info=None,
    number_of_cores=None,
    session=None,
)

# %% [markdown]
# __Redshifts__
#
# The redshifts of the lens and source galaxies, which are used to perform unit converions of the model and data (e.g.
# from arc-seconds to kiloparsecs, masses to solar masses, etc.).

# %%
redshift_lens = 0.5
redshift_source = 1.0

# %% [markdown]
# __HYPER SETUP__
#
# The `SetupHyper` determines which hyper-mode features are used during the model-fit.

# %%
setup_hyper = al.SetupHyper(
    hyper_galaxies_lens=False,
    hyper_galaxies_source=False,
    hyper_image_sky=None,
    hyper_background_noise=None,
)

# %% [markdown]
# __SOURCE PARAMETRIC PIPELINE (with lens light)__
#
# The SOURCE PARAMETRIC PIPELINE (with lens light) uses three searches to initialize a robust model for the
# source galaxy's light, which in this example:
#
#  - Uses a parametric `EllSersic` bulge and `EllExponential` disk with centres aligned for the lens
#  galaxy's light.
#
#  - Uses an `EllIsothermal` model for the lens's total mass distribution with an `ExternalShear`.
#
#  __Settings__:
#
#  - Mass Centre: Fix the mass profile centre to (0.0, 0.0) (this assumption will be relaxed in the MASS TOTAL PIPELINE).

# %%
analysis = al.AnalysisImaging(dataset=imaging)

bulge = af.Model(al.lp.EllSersic)
disk = af.Model(al.lp.EllExponential)
bulge.centre = (0.0, 0.0)
disk.centre = (0.0, 0.0)

source_parametric_results = slam.source_parametric.with_lens_light(
    settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    lens_bulge=bulge,
    lens_disk=disk,
    mass=af.Model(al.mp.EllIsothermal),
    shear=af.Model(al.mp.ExternalShear),
    source_bulge=af.Model(al.lp.EllSersic),
    mass_centre=(0.0, 0.0),
    redshift_lens=redshift_lens,
    redshift_source=redshift_source,
)
# Out:
# 2021-05-18 15:01:53,345 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 10.86it/s, +75 | bound: 0 | nc: 1 | ncall: 77 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.084]
# 2021-05-18 15:01:53,547 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:53,613 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:53,667 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:53,954 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 65.95it/s, +200 | bound: 0 | nc: 1 | ncall: 202 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.209]
# 2021-05-18 15:01:54,014 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:54,218 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:54,399 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/dynesty/dynesty.py:390: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 2021-05-18 15:01:54,988 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 72.75it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:01:55,034 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:55,272 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:55,497 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __LIGHT PARAMETRIC PIPELINE__
#
# The LIGHT PARAMETRIC PIPELINE uses one search to fit a complex lens light model to a high level of accuracy, using the
# lens mass model and source light model fixed to the maximum log likelihood result of the SOURCE PARAMETRIC PIPELINE.
# In this example it:
#
#  - Uses a parametric `EllSersic` bulge and `EllSersic` disk with centres aligned for the lens galaxy's
#  light [Do not use the results of the SOURCE PARAMETRIC PIPELINE to initialize priors].
#
#  - Uses an `EllIsothermal` model for the lens's total mass distribution [fixed from SOURCE PARAMETRIC PIPELINE].
#
#  - Uses the `EllSersic` model representing a bulge for the source's light [fixed from SOURCE PARAMETRIC PIPELINE].
#
#  - Carries the lens redshift, source redshift and `ExternalShear` of the SOURCE PIPELINE through to the MASS
#  PIPELINE [fixed values].

# %%
analysis = al.AnalysisImaging(
    dataset=imaging, hyper_result=source_parametric_results.last
)

bulge = af.Model(al.lp.EllSersic)
disk = af.Model(al.lp.EllExponential)
bulge.centre = disk.centre

light_results = slam.light_parametric.with_lens_light(
    settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    source_results=source_parametric_results,
    lens_bulge=bulge,
    lens_disk=disk,
)
# Out:
# 2021-05-18 15:01:56,337 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 70.24it/s, +75 | bound: 0 | nc: 1 | ncall: 77 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.084]
# 2021-05-18 15:01:56,380 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:56,487 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:56,578 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __MASS TOTAL PIPELINE (with lens light)__
#
# The MASS TOTAL PIPELINE (with lens light) uses one search to fits a complex lens mass model to a high level of accuracy,
# using the lens mass model and source model of the SOURCE PIPELINE to initialize the model priors and the lens light
# model of the LIGHT PARAMETRIC PIPELINE. In this example it:
#
#  - Uses a parametric `EllSersic` bulge and `EllSersic` disk with centres aligned for the lens galaxy's
#  light [fixed from LIGHT PARAMETRIC PIPELINE].
#
#  - Uses an `EllPowerLaw` model for the lens's total mass distribution [priors initialized from SOURCE
#  PARAMETRIC PIPELINE + centre unfixed from (0.0, 0.0)].
#
#  - Uses the `EllSersic` model representing a bulge for the source's light [priors initialized from SOURCE
#  PARAMETRIC PIPELINE].
#
#  - Carries the lens redshift, source redshift and `ExternalShear` of the SOURCE PIPELINE through to the MASS TOTAL PIPELINE.

# %%
analysis = al.AnalysisImaging(dataset=imaging)

mass_results = slam.mass_total.with_lens_light(
    settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    source_results=source_parametric_results,
    light_results=light_results,
    mass=af.Model(al.mp.EllPowerLaw),
)
# Out:
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/dynesty/dynesty.py:390: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 2021-05-18 15:01:57,300 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 50.44it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:01:57,358 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:57,548 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:57,728 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __SUBHALO PIPELINE (single plane detection)__
#
# The SUBHALO PIPELINE (single plane detection) consists of the following searches:
#
#  1) Refit the lens and source model, to refine the model evidence for comparing to the models fitted which include a
#  subhalo. This uses the same model as fitted in the MASS TOTAL PIPELINE.
#  2) Performs a grid-search of non-linear searches to attempt to detect a dark matter subhalo.
#  3) If there is a successful detection a final search is performed to refine its parameters.
#
# For this runner the SUBHALO PIPELINE customizes:
#
#  - The [number_of_steps x number_of_steps] size of the grid-search, as well as the dimensions it spans in arc-seconds.
#  - The `number_of_cores` used for the gridsearch, where `number_of_cores > 1` performs the model-fits in paralle using
#  the Python multiprocessing module.

# %%
analysis = al.AnalysisImaging(dataset=imaging)

subhalo_results = slam.subhalo.detection_single_plane(
    settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    mass_results=mass_results,
    subhalo_mass=af.Model(al.mp.SphNFWMCRLudlow),
    grid_dimension_arcsec=3.0,
    number_of_steps=5,
)
# Out:
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/dynesty/dynesty.py:390: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 2021-05-18 15:01:58,401 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 50.14it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:01:58,459 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:58,654 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:01:58,838 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/dynesty/dynesty.py:390: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 2021-05-18 15:01:59,907 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00,  3.14it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:00,559 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:00,814 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:01,070 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:01,488 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.74it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:01,552 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:01,802 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:02,045 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:02,445 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.83it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:02,508 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:02,761 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:03,010 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:03,414 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.12it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:03,477 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:03,736 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:03,973 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:04,380 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.41it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:04,442 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:04,696 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:04,938 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:05,349 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.77it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:05,411 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:05,673 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:05,921 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:06,326 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.26it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:06,389 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:06,654 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:06,900 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:07,305 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 42.13it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:07,366 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:07,615 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:07,861 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:08,268 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.57it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:08,332 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:08,592 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:08,832 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:09,233 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 34.97it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:09,304 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:09,556 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:09,797 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:10,206 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.64it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:10,268 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:10,526 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:10,775 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:11,183 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.26it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:11,250 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:11,506 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:11,749 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:12,152 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.72it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:12,214 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:12,470 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:12,717 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:13,125 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.39it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:13,186 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:13,440 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:13,687 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:14,091 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.19it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:14,154 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:14,407 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:14,653 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:15,056 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.80it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:15,118 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:15,375 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:15,627 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:16,035 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.12it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:16,099 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:16,350 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:16,596 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:17,006 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.13it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:17,068 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:17,327 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:17,569 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:17,983 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.57it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:18,047 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:18,302 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:18,541 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:18,948 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.81it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:19,009 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:19,262 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:19,505 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:19,919 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.15it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:19,983 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:20,240 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:20,487 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:20,891 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.18it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:20,954 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:21,209 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:21,453 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:21,860 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.10it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:21,923 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:22,179 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:22,424 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:22,825 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 36.87it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:22,895 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:23,158 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:23,399 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:23,803 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.48it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:02:23,869 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:24,126 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:24,366 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:25,153 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.14it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:02:25,220 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:25,506 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:02:25,768 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# Finish.
