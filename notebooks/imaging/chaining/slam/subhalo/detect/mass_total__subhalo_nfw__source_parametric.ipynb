# %% [markdown]
# SLaM (Source, Light and Mass): Mass Total + Subhalo NFW + Source Parametric
# ===========================================================================
#
# SLaM pipelines break the analysis down into multiple pipelines which focus on modeling a specific aspect of the strong
# lens, first the Source, then the (lens) Light and finally the Mass. Each of these pipelines has it own inputs which
# which customize the model and analysis in that pipeline.
#
# The models fitted in earlier pipelines determine the model used in later pipelines. For example, if the SOURCE PIPELINE
# uses a parametric `EllSersic` profile for the bulge, this will be used in the subsequent MASS TOTAL PIPELINE.
#
# Using a SOURCE PARAMETRIC PIPELINE, MASS TOTAL PIPELINE and SUBHALO PIPELINE this SLaM script fits `Imaging` of a strong lens
# system, where in the final model:
#
#  - The lens galaxy's light is omitted from the data and model.
#  - The lens galaxy's total mass distribution is an `EllIsothermal`.
#  - A dark matter subhalo near The lens galaxy mass is included as a`SphNFWMCRLudLow`.
#  - The source galaxy is an `EllSersic`.
#
# This uses the SLaM pipelines:
#
#  `source_parametric/no_lens_light`
#  `mass_total/no_lens_light`
#  `subhalo/detection_single_plane`
#
# Check them out for a full description of the analysis!

# %%
# %matplotlib inline
from pyprojroot import here
workspace_path = str(here())
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

import os
import sys
from os import path
import autofit as af
import autolens as al
import autolens.plot as aplt

sys.path.insert(0, os.getcwd())
import slam
# Out:
# /mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace
# Working Directory has been set to `/mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace`

# %% [markdown]
# __Dataset + Masking__
#
# Load, plot and mask the `Imaging` data.

# %%
dataset_name = "mass_sie__subhalo_nfw__source_sersic"
dataset_path = path.join("dataset", "imaging", "subhalo", dataset_name)

imaging = al.Imaging.from_fits(
    image_path=path.join(dataset_path, "image.fits"),
    noise_map_path=path.join(dataset_path, "noise_map.fits"),
    psf_path=path.join(dataset_path, "psf.fits"),
    pixel_scales=0.05,
)

mask = al.Mask2D.circular(
    shape_native=imaging.shape_native, pixel_scales=imaging.pixel_scales, radius=3.0
)

imaging = imaging.apply_mask(mask=mask)

imaging_plotter = aplt.ImagingPlotter(imaging=imaging)
imaging_plotter.subplot_imaging()

# %% [markdown]
# __Settings AutoFit__
#
# The settings of autofit, which controls the output paths, parallelization, database use, etc.

# %%
settings_autofit = slam.SettingsAutoFit(
    path_prefix=path.join("imaging", "slam"),
    unique_tag=dataset_name,
    info=None,
    number_of_cores=None,
    session=None,
)

# %% [markdown]
# __Redshifts__
#
# The redshifts of the lens and source galaxies, which are used to perform unit converions of the model and data (e.g.
# from arc-seconds to kiloparsecs, masses to solar masses, etc.).

# %%
redshift_lens = 0.5
redshift_source = 1.0

# %% [markdown]
# __HYPER SETUP__
#
# The `SetupHyper` determines which hyper-mode features are used during the model-fit.

# %%
setup_hyper = al.SetupHyper(
    hyper_galaxies_lens=False,
    hyper_galaxies_source=False,
    hyper_image_sky=None,
    hyper_background_noise=None,
)

# %% [markdown]
# __SOURCE PARAMETRIC PIPELINE (no lens light)__
#
# The SOURCE PARAMETRIC PIPELINE (no lens light) uses one search to initialize a robust model for the source galaxy's
# light, which in this example:
#
#  - Uses a parametric `EllSersic` bulge for the source's light (omitting a disk / envelope).
#  - Uses an `EllIsothermal` model for the lens's total mass distribution with an `ExternalShear`.
#
#  __Settings__:
#
#  - Mass Centre: Fix the mass profile centre to (0.0, 0.0) (this assumption will be relaxed in the MASS TOTAL PIPELINE).

# %%
analysis = al.AnalysisImaging(dataset=imaging)

source_parametric_results = slam.source_parametric.no_lens_light(
    settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    mass=af.Model(al.mp.EllIsothermal),
    shear=af.Model(al.mp.ExternalShear),
    source_bulge=af.Model(al.lp.EllSersic),
    mass_centre=(0.0, 0.0),
    redshift_lens=0.5,
    redshift_source=1.0,
)
# Out:
# 2021-05-18 15:03:44,627 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 10.58it/s, +200 | bound: 0 | nc: 1 | ncall: 202 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.209]
# 2021-05-18 15:03:44,850 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:45,033 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:45,184 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __MASS TOTAL PIPELINE (no lens light)__
#
# The MASS TOTAL PIPELINE (no lens light) uses one search to fits a complex lens mass model to a high level of accuracy,
# using the lens mass model and source model of the SOURCE PIPELINE to initialize the model priors. In this example it:
#
#  - Uses an `EllPowerLaw` model for the lens's total mass distribution [The centre if unfixed from (0.0, 0.0)].
#  - Uses the `EllSersic` model representing a bulge for the source's light.
#  - Carries the lens redshift, source redshift and `ExternalShear` of the SOURCE PIPELINE through to the MASS TOTAL PIPELINE.

# %%
analysis = al.AnalysisImaging(dataset=imaging)

mass_results = slam.mass_total.no_lens_light(
    settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    source_results=source_parametric_results,
    mass=af.Model(al.mp.EllPowerLaw),
)
# Out:
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/dynesty/dynesty.py:390: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 2021-05-18 15:03:45,844 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 58.80it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:03:45,897 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:46,075 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:46,229 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __SUBHALO PIPELINE (single plane detection)__
#
# The SUBHALO PIPELINE (single plane detection) consists of the following searches:
#
#  1) Refit the lens and source model, to refine the model evidence for comparing to the models fitted which include a
#  subhalo. This uses the same model as fitted in the MASS TOTAL PIPELINE.
#  2) Performs a grid-search of non-linear searches to attempt to detect a dark matter subhalo.
#  3) If there is a successful detection a final search is performed to refine its parameters.
#
# For this runner the SUBHALO PIPELINE customizes:
#
#  - The [number_of_steps x number_of_steps] size of the grid-search, as well as the dimensions it spans in arc-seconds.
#  - The `number_of_cores` used for the gridsearch, where `number_of_cores > 1` performs the model-fits in paralle using
#  the Python multiprocessing module.

# %%
analysis = al.AnalysisImaging(dataset=imaging)

subhalo_results = slam.subhalo.detection_single_plane(
    settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    mass_results=mass_results,
    subhalo_mass=af.Model(al.mp.SphNFWMCRLudlow),
    grid_dimension_arcsec=3.0,
    number_of_steps=5,
)
# Out:
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/dynesty/dynesty.py:390: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 2021-05-18 15:03:46,862 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 55.60it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:03:46,917 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:47,114 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:47,283 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/dynesty/dynesty.py:390: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 2021-05-18 15:03:48,321 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00,  3.17it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:48,967 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:49,206 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:49,429 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:49,804 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 43.62it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:49,865 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:50,100 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:50,322 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:50,698 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 44.53it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:50,756 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:50,985 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:51,231 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:51,632 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 43.26it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:51,692 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:51,927 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:52,151 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:52,530 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.79it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:52,587 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:52,822 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:53,043 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:53,422 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.26it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:53,480 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:53,724 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:53,954 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:54,341 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.99it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:54,405 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:54,634 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:54,856 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:55,234 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 44.98it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:55,292 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:55,525 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:55,754 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:56,124 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 44.00it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:56,184 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:56,423 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:56,651 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:57,030 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 46.10it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:57,086 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:57,318 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:57,537 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:57,909 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.85it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:57,966 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:58,207 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:58,425 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:58,800 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 44.80it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:58,858 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:59,093 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:59,318 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:59,693 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 44.47it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:03:59,752 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:03:59,980 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:00,196 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:00,563 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 46.45it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:00,619 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:00,854 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:01,086 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:01,463 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 44.80it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:01,521 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:01,757 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:01,978 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:02,354 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 46.92it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:02,410 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:02,643 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:02,870 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:03,237 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.74it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:03,294 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:03,524 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:03,741 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:04,120 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 44.82it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:04,178 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:04,412 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:04,643 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:05,018 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.48it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:05,076 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:05,312 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:05,531 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:05,910 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.14it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:05,968 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:06,196 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:06,422 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:06,800 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 44.74it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:06,858 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:07,093 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:07,315 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:07,692 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.94it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:07,750 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:07,983 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:08,212 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:08,586 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 47.27it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:08,641 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:08,871 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:09,095 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:09,469 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.80it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:09,525 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:09,755 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:09,977 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:10,350 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 47.11it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:04:10,407 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:10,640 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:10,865 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:11,623 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.89it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:04:11,685 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:11,946 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:04:12,193 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# Finish.
