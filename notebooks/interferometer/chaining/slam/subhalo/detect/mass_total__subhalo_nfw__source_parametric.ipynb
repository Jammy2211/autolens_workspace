# %% [markdown]
# SLaM (Source, Light and Mass): Mass Total + Subhalo NFW + Source Parametric
# ===========================================================================
#
# SLaM pipelines break the analysis down into multiple pipelines which focus on modeling a specific aspect of the strong
# lens, first the Source, then the (lens) Light and finally the Mass. Each of these pipelines has it own inputs which
# which customize the model and analysis in that pipeline.
#
# The models fitted in earlier pipelines determine the model used in later pipelines. For example, if the SOURCE PIPELINE
# uses a parametric `EllSersic` profile for the bulge, this will be used in the subsequent MASS TOTAL PIPELINE.
#
# Using a SOURCE PARAMETRIC PIPELINE, MASS TOTAL PIPELINE and SUBHALO PIPELINE this SLaM script fits `Interferometer` of a strong lens
# system, where in the final model:
#
#  - The lens galaxy's light is omitted from the data and model.
#  - The lens galaxy's total mass distribution is an `EllIsothermal`.
#  - A dark matter subhalo near The lens galaxy mass is included as a`SphNFWMCRLudLow`.
#  - The source galaxy is an `EllSersic`.
#
# This uses the SLaM pipelines:
#
#  `source_parametric/no_lens_light`
#  `mass_total/no_lens_light`
#  `subhalo/detection_single_plane`
#
# Check them out for a full description of the analysis!

# %%
# %matplotlib inline
from pyprojroot import here
workspace_path = str(here())
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

import os
import sys
from os import path
import autofit as af
import autolens as al
import autolens.plot as aplt

sys.path.insert(0, os.getcwd())
import slam
# Out:
# /mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace
# Working Directory has been set to `/mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace`

# %% [markdown]
# __Dataset + Masking__
#
# Load the `Interferometer` data, define the visibility and real-space masks and plot them.

# %%
real_space_mask = al.Mask2D.circular(
    shape_native=(151, 151), pixel_scales=0.05, radius=3.0
)

dataset_name = "mass_sie__subhalo_nfw__source_sersic"
dataset_path = path.join("dataset", "interferometer", dataset_name)

interferometer = al.Interferometer.from_fits(
    visibilities_path=path.join(dataset_path, "visibilities.fits"),
    noise_map_path=path.join(dataset_path, "noise_map.fits"),
    uv_wavelengths_path=path.join(dataset_path, "uv_wavelengths.fits"),
    real_space_mask=real_space_mask,
)
interferometer = interferometer.apply_settings(
    settings=al.SettingsInterferometer(transformer_class=al.TransformerNUFFT)
)

interferometer_plotter = aplt.InterferometerPlotter(interferometer=interferometer)
interferometer_plotter.subplot_interferometer()
interferometer_plotter.subplot_dirty_images()
# Out:
# /mnt/c/Users/Jammy/Code/PyAuto/PyAutoArray/autoarray/plot/mat_wrap/mat_plot.py:178: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(rows, columns, self.subplot_index)
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/pynufft/linalg/nufft_cpu.py:381: ComplexWarning: Casting complex values to real discards the imaginary part
#   xx.ravel()[self.NdCPUorder * self.batch + bat] = k.ravel()[
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/pynufft/linalg/nufft_cpu.py:381: ComplexWarning: Casting complex values to real discards the imaginary part
#   xx.ravel()[self.NdCPUorder * self.batch + bat] = k.ravel()[

# %% [markdown]
# __Settings AutoFit__
#
# The settings of autofit, which controls the output paths, parallelization, database use, etc.

# %%
settings_autofit = slam.SettingsAutoFit(
    path_prefix=path.join("interferometer", "slam"),
    unique_tag=dataset_name,
    info=None,
    number_of_cores=None,
    session=None,
)

# %% [markdown]
# __Redshifts__
#
# The redshifts of the lens and source galaxies, which are used to perform unit converions of the model and data (e.g.
# from arc-seconds to kiloparsecs, masses to solar masses, etc.).

# %%
redshift_lens = 0.5
redshift_source = 1.0

# %% [markdown]
# __HYPER SETUP__
#
# The `SetupHyper` determines which hyper-mode features are used during the model-fit.

# %%
setup_hyper = al.SetupHyper(
    hyper_galaxies_lens=False,
    hyper_galaxies_source=False,
    hyper_image_sky=None,
    hyper_background_noise=None,
)

# %% [markdown]
# __SOURCE PARAMETRIC PIPELINE (no lens light)__
#
# The SOURCE PARAMETRIC PIPELINE (no lens light) uses one search to initialize a robust model for the source galaxy's
# light, which in this example:
#
#  - Uses a parametric `EllSersic` bulge for the source's light (omitting a disk / envelope).
#  - Uses an `EllIsothermal` model for the lens's total mass distribution with an `ExternalShear`.
#
#  __Settings__:
#
#  - Mass Centre: Fix the mass profile centre to (0.0, 0.0) (this assumption will be relaxed in the MASS TOTAL PIPELINE).

# %%
analysis = al.AnalysisInterferometer(dataset=interferometer)

source_parametric_results = slam.source_parametric.no_lens_light(
settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    mass=af.Model(al.mp.EllIsothermal),
    shear=af.Model(al.mp.ExternalShear),
    source_bulge=af.Model(al.lp.EllSersic),
    mass_centre=(0.0, 0.0),
    redshift_lens=0.5,
    redshift_source=1.0,
)
# Out:
# 2021-05-18 15:35:36,630 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 62.66it/s, +200 | bound: 0 | nc: 1 | ncall: 202 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.209]
# 2021-05-18 15:35:36,699 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:36,900 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:37,078 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __MASS TOTAL PIPELINE (no lens light)__
#
# The MASS TOTAL PIPELINE (no lens light) uses one search to fits a complex lens mass model to a high level of accuracy,
# using the lens mass model and source model of the SOURCE PIPELINE to initialize the model priors. In this example it:
#
#  - Uses an `EllPowerLaw` model for the lens's total mass distribution [The centre if unfixed from (0.0, 0.0)].
#  - Uses the `EllSersic` model representing a bulge for the source's light.
#  - Carries the lens redshift, source redshift and `ExternalShear` of the SOURCE PIPELINE through to the MASS TOTAL PIPELINE.

# %%
analysis = al.AnalysisInterferometer(dataset=interferometer)

mass_results = slam.mass_total.no_lens_light(
settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    source_results=source_parametric_results,
    mass=af.Model(al.mp.EllPowerLaw),
)
# Out:
# 2021-05-18 15:35:37,746 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 42.68it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:35:37,818 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:38,010 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:38,184 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __SUBHALO PIPELINE (single plane detection)__
#
# The SUBHALO PIPELINE (single plane detection) consists of the following searches:
#
#  1) Refit the lens and source model, to refine the model evidence for comparing to the models fitted which include a
#  subhalo. This uses the same model as fitted in the MASS TOTAL PIPELINE.
#  2) Performs a grid-search of non-linear searches to attempt to detect a dark matter subhalo.
#  3) If there is a successful detection a final search is performed to refine its parameters.
#
# For this runner the SUBHALO PIPELINE customizes:
#
#  - The [number_of_steps x number_of_steps] size of the grid-search, as well as the dimensions it spans in arc-seconds.
#  - The `number_of_cores` used for the gridsearch, where `number_of_cores > 1` performs the model-fits in paralle using
#  the Python multiprocessing module.

# %%
analysis = al.AnalysisInterferometer(dataset=interferometer)

subhalo_results = slam.subhalo.detection_single_plane(
settings_autofit=settings_autofit,
    analysis=analysis,
    setup_hyper=setup_hyper,
    mass_results=mass_results,
    subhalo_mass=af.Model(al.mp.SphNFWMCRLudlow),
    grid_dimension_arcsec=3.0,
    number_of_steps=5,
)
# Out:
# 2021-05-18 15:35:38,857 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.50it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:35:38,922 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:39,114 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:39,289 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:39,802 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00,  2.94it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:40,499 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:40,747 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:40,984 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:41,376 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.10it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:41,441 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:41,687 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:41,919 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:42,315 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 37.74it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:42,384 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:42,632 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:42,860 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:43,263 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 32.86it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:43,339 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:43,592 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:43,826 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:44,212 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 37.48it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:44,281 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:44,533 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:44,772 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:45,165 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.00it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:45,231 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:45,479 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:45,714 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:46,100 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 36.44it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:46,173 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:46,421 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:46,662 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:47,052 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.13it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:47,118 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:47,359 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:47,592 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:47,978 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.82it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:48,049 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:48,324 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:48,585 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:49,015 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 30.56it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:49,099 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:49,375 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:49,637 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:50,042 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 30.96it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:50,123 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:50,387 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:50,655 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:51,122 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 31.03it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:51,208 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:51,539 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:51,829 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:52,420 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 20.57it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:52,538 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:52,828 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:53,095 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:53,488 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 36.69it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:53,558 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:53,806 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:54,057 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:54,482 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 33.44it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:54,559 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:54,822 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:55,063 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:55,461 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.82it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:55,528 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:55,792 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:56,056 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:56,533 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 33.96it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:56,608 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:56,981 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:57,264 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:57,678 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 37.26it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:57,748 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:58,015 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:58,263 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:58,660 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 37.03it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:58,729 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:58,977 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:59,220 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:59,613 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 36.75it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:35:59,683 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:35:59,929 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:00,171 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:00,613 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 34.84it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:36:00,685 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:00,960 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:01,198 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:01,597 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 35.46it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:36:01,670 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:01,933 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:02,180 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:02,578 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 36.94it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:36:02,648 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:02,895 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:03,133 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:03,539 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 37.39it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:36:03,609 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:03,852 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:04,082 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:04,474 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 33.50it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-18 15:36:04,551 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:04,800 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:05,042 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:05,837 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.40it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-18 15:36:05,911 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:06,196 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-18 15:36:06,451 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# Finish.
