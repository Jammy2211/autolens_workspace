# %% [markdown]
# __Non-linear Search__
#
# In this example, we're going to find a lens model that provides a good fit to an image, without assuming any knowledge of what the 'correct' lens model is.
#
# So, whats a 'lens model'? It is the combination of light profiles and mass profiles we use to represent a lens galaxy,source galaxy and therefore the strong lens ray-tracing configuration (i.e. a tracer).
#
# To begin, we have to choose the parametrization of our lens model. We don't need to specify the values of its light and mass profiles (e.g. the centre, einstein_radius, etc.) - only the profiles themselves. In this example, we'll use the following lens model:
#
# 1) A spherical Isothermal Sphere (SIS) for the lens galaxy's mass.
# 2) A spherical exponential light profile for the source galaxy's light.
#
# I'll let you into a secret - this is the same lens model used to Simulate the Imaging data we're going to fit and we're going to infer the actual parameters I used.
#
# So, how do we infer the light and mass profile parameters that give a good fit to our data?
#
# Well, we could randomly guess a lens model, corresponding to some random set of parameters. We could use this lens model to create a tracer and fit the image-data, and quantify how good the fit was using its likelihood (recall chapter_1/tutorial_8). If we kept guessing lens models, eventually we'd find one that provides a good fit (i.e. high likelihood) to the data!
#
# It may sound surprising, but this is actually the basis of how lens modeling works. However, we can do a lot better than random guessing. Instead, we track the likelihood of our previous guesses and guess more models using combinations of parameters that gave higher likelihood solutions previously. The idea is that if a set of parameters provided a good fit to the data, another set with similar values probably will too.
#
# This is called a 'non-linear search' and its a fairly common problem faced by scientists. Over the next few tutorials, we're going to really get our heads around the concept of a non-linear search - intuition which will prove crucial to being a successful lens modeler.
#
# We're going to use a non-linear search algorithm called 'MultiNest'. I highly recommend it, and find its great for lens modeling. However, for now, lets not worry about the details of how MultiNest actually works. Instead, just picture that a non-linear search in PyAutoLens operates as follows:
#
# 1) Randomly guess a lens model and use its light-profiles and mass-profiles to set up a lens galaxy, source galaxy and a tracer.
#
# 2) Pass this tracer through the fitting module, generating a model image and comparing this model image to the observed strong lens imaging data. This computes a likelihood.
#
# 3) Repeat this many times, using the likelihoods of previous fits (typically those with a high likelihood) to guide us to the lens models with the highest likelihood.

# %%
# %matplotlib inline

# %% [markdown]
# In this chapter, we're not going to individually import every module we're used to importing. Instead, we can just import autolens (as 'al'), which is what we'll do to import all the modules we're used to from chapter 1. However, we'll indivdually import the modules new to this chapter (and we'll import them as 'al' in chapter 3).

# %%
import autolens as al
import autofit as af

# %% [markdown]
# You're going to see a line like the one below (with 'conf.instance') in every tutorial this chapter. I recommend that for now you just ignore it. A non-linear search can take a long time to run (minutes, hours, or days), and thisisn't ideal if you want to go through the tutorials without having to constant stop for long periods!
#
# This line overrides the configuration of the non-linear search such that it computes the solution really fast. To do this, I've 'cheated' - I've computed the solution myself and then input it into the config. Nevertheless, it means things will run fast for you, meaning you won't suffer long delays doing the tutorials.
#
# This will all become clear at the end of the chapter, so for now just bare in mind that we are taking a short-cut to get our non-linear search to run fast!
#
# You need to change the path below to the chapter 1 directory.

# %%
chapter_path = "/path/to/user/autolens_workspace/howtolens/chapter_2_lens_modeling/"
chapter_path = "/home/jammy/PycharmProjects/PyAuto/autolens_workspace/howtolens/chapter_2_lens_modeling/"

af.conf.instance = af.conf.Config(
    config_path=chapter_path + "/configs/t1_non_linear_search",
    output_path=chapter_path + "/output",
)

# %% [markdown]
# This function simulates the image we'll fit in this tutorial.

# %%
def simulate():

    psf = al.kernel.from_gaussian(shape_2d=(11, 11), sigma=0.1, pixel_scales=0.1)

    lens_galaxy = al.Galaxy(
        redshift=0.5,
        mass=al.mp.SphericalIsothermal(centre=(0.0, 0.0), einstein_radius=1.6),
    )

    source_galaxy = al.Galaxy(
        redshift=1.0,
        light=al.lp.SphericalExponential(
            centre=(0.0, 0.0), intensity=0.2, effective_radius=0.2
        ),
    )

    tracer = al.Tracer.from_galaxies(galaxies=[lens_galaxy, source_galaxy])

    simulator = al.simulator.imaging(
        shape_2d=(130, 130),
        pixel_scales=0.1,
        exposure_time=300.0,
        sub_size=1,
        psf=psf,
        background_level=0.1,
        add_noise=True,
    )

    return simulator.from_tracer(tracer=tracer)

# %% [markdown]
# Lets call the simulate function above, providing us with Imaging data to fit.

# %%
imaging = simulate()

al.plot.imaging.subplot(imaging=imaging)

# %% [markdown]
# To compute a lens model, we use a GalaxyModel, which behaves analogously to the Galaxy objects we're now used to. However, whereas for a Galaxy we manually specified the value of every parameter of its light-profiles and mass-profiles, for a GalaxyModel these are inferred by the non-linear search.
#
# Lets model the lens galaxy with an SIS mass profile (which is what it was simulated with).

# %%
lens_galaxy_model = al.GalaxyModel(redshift=0.5, mass=al.mp.SphericalIsothermal)

# %% [markdown]
# Lets model the source galaxy with a spherical exponential light profile (again, what it was simulated with).

# %%
source_galaxy_model = al.GalaxyModel(redshift=1.0, light=al.lp.SphericalExponential)

# %% [markdown]
# A phase takes our galaxy models and fits their parameters via a non-linear search (in this case, MultiNest).
#
# (Just like we could give profiles descriptive names, like 'light', 'bulge' and 'disk', we can do the exact same thing with the phase's galaxies. This is good practise - as once we start using complex lens models, you couldpotentially have a lot of galaxies - and this is the best way to keep track of them!).
#
# (ignore the 'dict' - its necessary syntax but not something you need to concern yourself with).

# %%
phase = al.PhaseImaging(
    phase_name="phase_t1_non_linear_search",
    galaxies=dict(lens_galaxy=lens_galaxy_model, source_galaxy=source_galaxy_model),
    optimizer_class=af.MultiNest,
)

# %% [markdown]
# To run the phase, we pass it the data we're going to fit a lens model to and the non-linear search begins! As the phase runs, a logger will show you the parameters of the best-fit model.

# %%
print(
    "MultiNest has begun running - checkout the workspace/howtolens/chapter_2_lens_modeling/output/1_non_linear_search"
    "folder for live output of the results, images and lens model."
    "This Jupyter notebook cell with progress once MultiNest has completed - this could take some time!"
)

results = phase.run(dataset=imaging)

print("MultiNest has finished run - you may now continue the notebook.")
# Out:
# MultiNest has begun running - checkout the workspace/howtolens/chapter_2_lens_modeling/output/1_non_linear_searchfolder for live output of the results, images and lens model.This Jupyter notebook cell with progress once MultiNest has completed - this could take some time!
# Recursion wrapper received item <autofit.mapper.model_mapper.ModelMapper object at 0x7ffa5652d748>
# This gives item_id 140713166821192. Cache keys =
# item not in cache
# Recursion wrapper received item 16
# This gives item_id 10914976. Cache keys = 140713166821192
# item not in cache
# Recursion wrapper received item <autofit.mapper.prior_model.collection.CollectionPriorModel object at 0x7ffa2ae1bf60>
# This gives item_id 140712437989216. Cache keys = 140713166821192
# item not in cache
# Recursion wrapper received item 17
# This gives item_id 10915008. Cache keys = 140713166821192,140712437989216
# item not in cache
# Recursion wrapper received item 0
# This gives item_id 10914464. Cache keys = 140713166821192,140712437989216
# item not in cache
# Recursion wrapper received item <autoastro.galaxy.galaxy_model.GalaxyModel object at 0x7ffa2b9db978>
# This gives item_id 140712450308472. Cache keys = 140713166821192,140712437989216
# item not in cache
# Recursion wrapper received item 2
# This gives item_id 10914528. Cache keys = 140713166821192,140712437989216,140712450308472
# item not in cache
# Recursion wrapper received item <class 'autoastro.galaxy.galaxy.Galaxy'>
# This gives item_id 65210216. Cache keys = 140713166821192,140712437989216,140712450308472
# item not in cache
# Recursion wrapper received item autoastro.galaxy.galaxy
# This gives item_id 140712451078736. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item
#     @DynamicAttrs
#
# This gives item_id 140712451079600. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.__init__ at 0x7ffa2ba99ea0>
# This gives item_id 140712451088032. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.__hash__ at 0x7ffa2ba99f28>
# This gives item_id 140712451088168. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3868>
# This gives item_id 140712451127400. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa38b8>
# This gives item_id 140712451127480. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3908>
# This gives item_id 140712451127560. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3958>
# This gives item_id 140712451127640. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa39a8>
# This gives item_id 140712451127720. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa39f8>
# This gives item_id 140712451127800. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3a48>
# This gives item_id 140712451127880. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3a98>
# This gives item_id 140712451127960. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3ae8>
# This gives item_id 140712451128040. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3b38>
# This gives item_id 140712451128120. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3b88>
# This gives item_id 140712451128200. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3bd8>
# This gives item_id 140712451128280. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3c28>
# This gives item_id 140712451128360. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3c78>
# This gives item_id 140712451128440. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3cc8>
# This gives item_id 140712451128520. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3d18>
# This gives item_id 140712451128600. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3d68>
# This gives item_id 140712451128680. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3db8>
# This gives item_id 140712451128760. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3e08>
# This gives item_id 140712451128840. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.__repr__ at 0x7ffa2baaaa60>
# This gives item_id 140712451156576. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.__eq__ at 0x7ffa2baaaae8>
# This gives item_id 140712451156712. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.new_object_with_units_converted at 0x7ffa2baaab70>
# This gives item_id 140712451156848. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.profile_image_from_grid at 0x7ffa2baaabf8>
# This gives item_id 140712451156984. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.blurred_profile_image_from_grid_and_psf at 0x7ffa2baaac80>
# This gives item_id 140712451157120. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.blurred_profile_image_from_grid_and_convolver at 0x7ffa2baaad08>
# This gives item_id 140712451157256. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.profile_visibilities_from_grid_and_transformer at 0x7ffa2baaad90>
# This gives item_id 140712451157392. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.luminosity_within_circle_in_units at 0x7ffa2baaae18>
# This gives item_id 140712451157528. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.convergence_from_grid at 0x7ffa2baaaea0>
# This gives item_id 140712451157664. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.potential_from_grid at 0x7ffa2baaaf28>
# This gives item_id 140712451157800. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.deflections_from_grid at 0x7ffa2baab048>
# This gives item_id 140712451158088. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.mass_within_circle_in_units at 0x7ffa2baab0d0>
# This gives item_id 140712451158224. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.summarize_in_units at 0x7ffa2baab158>
# This gives item_id 140712451158360. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.summarize_light_profiles_in_units at 0x7ffa2baab1e0>
# This gives item_id 140712451158496. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.summarize_mass_profiles_in_units at 0x7ffa2baab268>
# This gives item_id 140712451158632. Cache keys = 140713166821192,140712437989216,140712450308472,65210216
# item not in cache
# Recursion wrapper received item 0.5
# This gives item_id 140712453926032. Cache keys = 140713166821192,140712437989216,140712450308472
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712450308472
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712450308472
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712450308472
# item not in cache
# Recursion wrapper received item <autofit.mapper.prior_model.prior_model.PriorModel object at 0x7ffa2ae874e0>
# This gives item_id 140712438428896. Cache keys = 140713166821192,140712437989216,140712450308472
# item not in cache
# Recursion wrapper received item 3
# This gives item_id 10914560. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896
# item not in cache
# Recursion wrapper received item <class 'autoastro.profiles.mass_profiles.total_mass_profiles.SphericalIsothermal'>
# This gives item_id 65134520. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896
# item not in cache
# Recursion wrapper received item autoastro.profiles.mass_profiles.total_mass_profiles
# This gives item_id 140712454065352. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.__init__ at 0x7ffa2bd29268>
# This gives item_id 140712453771880. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.__init__ at 0x7ffa2bd291e0>
# This gives item_id 140712453771744. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520,140712453771880
# item not in cache
# Recursion wrapper received item def __init__(self, centre, einstein_radius):
#     return _call_(_func_, self, centre, einstein_radius)
#
# This gives item_id 140712454182584. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520,140712453771880
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.potential_from_grid at 0x7ffa2bd29400>
# This gives item_id 140712453772288. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.potential_from_grid at 0x7ffa2bd29378>
# This gives item_id 140712453772152. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520,140712453772288
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.potential_from_grid at 0x7ffa2bd292f0>
# This gives item_id 140712453772016. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520,140712453772288,140712453772152
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.deflections_from_grid at 0x7ffa2bd29598>
# This gives item_id 140712453772696. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.deflections_from_grid at 0x7ffa2bd29510>
# This gives item_id 140712453772560. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520,140712453772696
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.deflections_from_grid at 0x7ffa2bd29488>
# This gives item_id 140712453772424. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520,140712453772696,140712453772560
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,65134520
# item not in cache
# Recursion wrapper received item <autofit.mapper.prior_model.prior.TuplePrior object at 0x7ffa2ae872e8>
# This gives item_id 140712438428392. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896
# item not in cache
# Recursion wrapper received item GaussianPrior, mean = 0.0, sigma = 0.02
# This gives item_id 140712438083936. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392
# item not in cache
# Recursion wrapper received item 4
# This gives item_id 10914592. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438083936
# item not in cache
# Recursion wrapper received item -inf
# This gives item_id 140712413053648. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438083936
# item not in cache
# Recursion wrapper received item inf
# This gives item_id 140712413053768. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438083936
# item not in cache
# Recursion wrapper received item 0.0
# This gives item_id 140712413652528. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438083936
# item not in cache
# Recursion wrapper received item 0.02
# This gives item_id 140712413653344. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438083936
# item not in cache
# Recursion wrapper received item GaussianPrior, mean = 0.0, sigma = 0.02
# This gives item_id 140712438430912. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392
# item not in cache
# Recursion wrapper received item 5
# This gives item_id 10914624. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438430912
# item not in cache
# Recursion wrapper received item -inf
# This gives item_id 140712413053720. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438430912
# item not in cache
# Recursion wrapper received item inf
# This gives item_id 140712413053456. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438430912
# item not in cache
# Recursion wrapper received item 0.0
# This gives item_id 140712413053744. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438430912
# item not in cache
# Recursion wrapper received item 0.02
# This gives item_id 140712413053696. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438428392,140712438430912
# item not in cache
# Recursion wrapper received item <autofit.mapper.prior_model.annotation.AnnotationPriorModel object at 0x7ffa2ae87588>
# This gives item_id 140712438429064. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896
# item not in cache
# Recursion wrapper received item <class 'autoastro.profiles.mass_profiles.total_mass_profiles.SphericalIsothermal'>
# This gives item_id 65134520. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064
# item not in cache
# Recursion wrapper received item autoastro.profiles.mass_profiles.total_mass_profiles
# This gives item_id 140712454065352. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.__init__ at 0x7ffa2bd29268>
# This gives item_id 140712453771880. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.__init__ at 0x7ffa2bd291e0>
# This gives item_id 140712453771744. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520,140712453771880
# item not in cache
# Recursion wrapper received item def __init__(self, centre, einstein_radius):
#     return _call_(_func_, self, centre, einstein_radius)
#
# This gives item_id 140712454182584. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520,140712453771880
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.potential_from_grid at 0x7ffa2bd29400>
# This gives item_id 140712453772288. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.potential_from_grid at 0x7ffa2bd29378>
# This gives item_id 140712453772152. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520,140712453772288
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.potential_from_grid at 0x7ffa2bd292f0>
# This gives item_id 140712453772016. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520,140712453772288,140712453772152
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.deflections_from_grid at 0x7ffa2bd29598>
# This gives item_id 140712453772696. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.deflections_from_grid at 0x7ffa2bd29510>
# This gives item_id 140712453772560. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520,140712453772696
# item not in cache
# Recursion wrapper received item <function SphericalIsothermal.deflections_from_grid at 0x7ffa2bd29488>
# This gives item_id 140712453772424. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520,140712453772696,140712453772560
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65134520
# item not in cache
# Recursion wrapper received item einstein_radius
# This gives item_id 140712454133936. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064
# item not in cache
# Recursion wrapper received item 6
# This gives item_id 10914656. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064
# item not in cache
# Recursion wrapper received item <class 'autoastro.dimensions.Length'>
# This gives item_id 65106296. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064
# item not in cache
# Recursion wrapper received item autoastro.dimensions
# This gives item_id 140712478470336. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65106296
# item not in cache
# Recursion wrapper received item <function Length.__init__ at 0x7ffa2bd5ab70>
# This gives item_id 140712453974896. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65106296
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2d1a0e08>
# This gives item_id 140712475233800. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65106296
# item not in cache
# Recursion wrapper received item <function Length.convert at 0x7ffa2bd5ac80>
# This gives item_id 140712453975168. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65106296
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,65106296
# item not in cache
# Recursion wrapper received item GaussianPrior, mean = 1.6, sigma = 0.01
# This gives item_id 140712438428952. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064
# item not in cache
# Recursion wrapper received item 7
# This gives item_id 10914688. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,140712438428952
# item not in cache
# Recursion wrapper received item 0.0
# This gives item_id 140712413053792. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,140712438428952
# item not in cache
# Recursion wrapper received item inf
# This gives item_id 140712413053816. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,140712438428952
# item not in cache
# Recursion wrapper received item 1.6
# This gives item_id 140712413053408. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,140712438428952
# item not in cache
# Recursion wrapper received item 0.01
# This gives item_id 140712413053864. Cache keys = 140713166821192,140712437989216,140712450308472,140712438428896,140712438429064,140712438428952
# item not in cache
# Recursion wrapper received item <autoastro.galaxy.galaxy_model.GalaxyModel object at 0x7ffa2ae876a0>
# This gives item_id 140712438429344. Cache keys = 140713166821192,140712437989216
# item not in cache
# Recursion wrapper received item 8
# This gives item_id 10914720. Cache keys = 140713166821192,140712437989216,140712438429344
# item not in cache
# Recursion wrapper received item <class 'autoastro.galaxy.galaxy.Galaxy'>
# This gives item_id 65210216. Cache keys = 140713166821192,140712437989216,140712438429344
# item not in cache
# Recursion wrapper received item autoastro.galaxy.galaxy
# This gives item_id 140712451078736. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item
#     @DynamicAttrs
#
# This gives item_id 140712451079600. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.__init__ at 0x7ffa2ba99ea0>
# This gives item_id 140712451088032. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.__hash__ at 0x7ffa2ba99f28>
# This gives item_id 140712451088168. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3868>
# This gives item_id 140712451127400. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa38b8>
# This gives item_id 140712451127480. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3908>
# This gives item_id 140712451127560. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3958>
# This gives item_id 140712451127640. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa39a8>
# This gives item_id 140712451127720. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa39f8>
# This gives item_id 140712451127800. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3a48>
# This gives item_id 140712451127880. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3a98>
# This gives item_id 140712451127960. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3ae8>
# This gives item_id 140712451128040. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3b38>
# This gives item_id 140712451128120. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3b88>
# This gives item_id 140712451128200. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3bd8>
# This gives item_id 140712451128280. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3c28>
# This gives item_id 140712451128360. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3c78>
# This gives item_id 140712451128440. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3cc8>
# This gives item_id 140712451128520. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3d18>
# This gives item_id 140712451128600. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3d68>
# This gives item_id 140712451128680. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3db8>
# This gives item_id 140712451128760. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2baa3e08>
# This gives item_id 140712451128840. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.__repr__ at 0x7ffa2baaaa60>
# This gives item_id 140712451156576. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.__eq__ at 0x7ffa2baaaae8>
# This gives item_id 140712451156712. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.new_object_with_units_converted at 0x7ffa2baaab70>
# This gives item_id 140712451156848. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.profile_image_from_grid at 0x7ffa2baaabf8>
# This gives item_id 140712451156984. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.blurred_profile_image_from_grid_and_psf at 0x7ffa2baaac80>
# This gives item_id 140712451157120. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.blurred_profile_image_from_grid_and_convolver at 0x7ffa2baaad08>
# This gives item_id 140712451157256. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.profile_visibilities_from_grid_and_transformer at 0x7ffa2baaad90>
# This gives item_id 140712451157392. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.luminosity_within_circle_in_units at 0x7ffa2baaae18>
# This gives item_id 140712451157528. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.convergence_from_grid at 0x7ffa2baaaea0>
# This gives item_id 140712451157664. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.potential_from_grid at 0x7ffa2baaaf28>
# This gives item_id 140712451157800. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.deflections_from_grid at 0x7ffa2baab048>
# This gives item_id 140712451158088. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.mass_within_circle_in_units at 0x7ffa2baab0d0>
# This gives item_id 140712451158224. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.summarize_in_units at 0x7ffa2baab158>
# This gives item_id 140712451158360. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.summarize_light_profiles_in_units at 0x7ffa2baab1e0>
# This gives item_id 140712451158496. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item <function Galaxy.summarize_mass_profiles_in_units at 0x7ffa2baab268>
# This gives item_id 140712451158632. Cache keys = 140713166821192,140712437989216,140712438429344,65210216
# item not in cache
# Recursion wrapper received item 1.0
# This gives item_id 140712413053840. Cache keys = 140713166821192,140712437989216,140712438429344
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712438429344
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712438429344
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712438429344
# item not in cache
# Recursion wrapper received item <autofit.mapper.prior_model.prior_model.PriorModel object at 0x7ffa2ae87550>
# This gives item_id 140712438429008. Cache keys = 140713166821192,140712437989216,140712438429344
# item not in cache
# Recursion wrapper received item 9
# This gives item_id 10914752. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008
# item not in cache
# Recursion wrapper received item <class 'autoastro.profiles.light_profiles.SphericalExponential'>
# This gives item_id 65162920. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008
# item not in cache
# Recursion wrapper received item autoastro.profiles.light_profiles
# This gives item_id 140712478387784. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,65162920
# item not in cache
# Recursion wrapper received item <function SphericalExponential.__init__ at 0x7ffa2bd7bc80>
# This gives item_id 140712454110336. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,65162920
# item not in cache
# Recursion wrapper received item <function SphericalExponential.__init__ at 0x7ffa2bd7bbf8>
# This gives item_id 140712454110200. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,65162920,140712454110336
# item not in cache
# Recursion wrapper received item def __init__(self, centre, intensity, effective_radius):
#     return _call_(_func_, self, centre, intensity, effective_radius)
#
# This gives item_id 140712475109136. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,65162920,140712454110336
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,65162920
# item not in cache
# Recursion wrapper received item <autofit.mapper.prior_model.prior.TuplePrior object at 0x7ffa2ae87278>
# This gives item_id 140712438428280. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008
# item not in cache
# Recursion wrapper received item GaussianPrior, mean = 0.0, sigma = 0.02
# This gives item_id 140712438427944. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280
# item not in cache
# Recursion wrapper received item 10
# This gives item_id 10914784. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438427944
# item not in cache
# Recursion wrapper received item -inf
# This gives item_id 140712413053984. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438427944
# item not in cache
# Recursion wrapper received item inf
# This gives item_id 140712413054008. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438427944
# item not in cache
# Recursion wrapper received item 0.0
# This gives item_id 140712413053888. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438427944
# item not in cache
# Recursion wrapper received item 0.02
# This gives item_id 140712413053912. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438427944
# item not in cache
# Recursion wrapper received item GaussianPrior, mean = 0.0, sigma = 0.02
# This gives item_id 140712438429176. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280
# item not in cache
# Recursion wrapper received item 11
# This gives item_id 10914816. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438429176
# item not in cache
# Recursion wrapper received item -inf
# This gives item_id 140712413054080. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438429176
# item not in cache
# Recursion wrapper received item inf
# This gives item_id 140712413054104. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438429176
# item not in cache
# Recursion wrapper received item 0.0
# This gives item_id 140712413053960. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438429176
# item not in cache
# Recursion wrapper received item 0.02
# This gives item_id 140712413054032. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438428280,140712438429176
# item not in cache
# Recursion wrapper received item <autofit.mapper.prior_model.annotation.AnnotationPriorModel object at 0x7ffa2ae87eb8>
# This gives item_id 140712438431416. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008
# item not in cache
# Recursion wrapper received item <class 'autoastro.profiles.light_profiles.SphericalExponential'>
# This gives item_id 65162920. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416
# item not in cache
# Recursion wrapper received item autoastro.profiles.light_profiles
# This gives item_id 140712478387784. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65162920
# item not in cache
# Recursion wrapper received item <function SphericalExponential.__init__ at 0x7ffa2bd7bc80>
# This gives item_id 140712454110336. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65162920
# item not in cache
# Recursion wrapper received item <function SphericalExponential.__init__ at 0x7ffa2bd7bbf8>
# This gives item_id 140712454110200. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65162920,140712454110336
# item not in cache
# Recursion wrapper received item def __init__(self, centre, intensity, effective_radius):
#     return _call_(_func_, self, centre, intensity, effective_radius)
#
# This gives item_id 140712475109136. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65162920,140712454110336
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65162920
# item not in cache
# Recursion wrapper received item intensity
# This gives item_id 140713215884848. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416
# item not in cache
# Recursion wrapper received item 12
# This gives item_id 10914848. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416
# item not in cache
# Recursion wrapper received item <class 'autoastro.dimensions.Luminosity'>
# This gives item_id 65107240. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416
# item not in cache
# Recursion wrapper received item autoastro.dimensions
# This gives item_id 140712478470336. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65107240
# item not in cache
# Recursion wrapper received item <function Luminosity.__init__ at 0x7ffa2bd5ad08>
# This gives item_id 140712453975304. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65107240
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2d1a0ef8>
# This gives item_id 140712475234040. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65107240
# item not in cache
# Recursion wrapper received item <function Luminosity.convert at 0x7ffa2bd5ae18>
# This gives item_id 140712453975576. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65107240
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,65107240
# item not in cache
# Recursion wrapper received item GaussianPrior, mean = 0.2, sigma = 0.01
# This gives item_id 140712438428840. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416
# item not in cache
# Recursion wrapper received item 13
# This gives item_id 10914880. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,140712438428840
# item not in cache
# Recursion wrapper received item 0.0
# This gives item_id 140712413054176. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,140712438428840
# item not in cache
# Recursion wrapper received item inf
# This gives item_id 140712413054200. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,140712438428840
# item not in cache
# Recursion wrapper received item 0.2
# This gives item_id 140712413054056. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,140712438428840
# item not in cache
# Recursion wrapper received item 0.01
# This gives item_id 140712413054128. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438431416,140712438428840
# item not in cache
# Recursion wrapper received item <autofit.mapper.prior_model.annotation.AnnotationPriorModel object at 0x7ffa2ae879b0>
# This gives item_id 140712438430128. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008
# item not in cache
# Recursion wrapper received item <class 'autoastro.profiles.light_profiles.SphericalExponential'>
# This gives item_id 65162920. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128
# item not in cache
# Recursion wrapper received item autoastro.profiles.light_profiles
# This gives item_id 140712478387784. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65162920
# item not in cache
# Recursion wrapper received item <function SphericalExponential.__init__ at 0x7ffa2bd7bc80>
# This gives item_id 140712454110336. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65162920
# item not in cache
# Recursion wrapper received item <function SphericalExponential.__init__ at 0x7ffa2bd7bbf8>
# This gives item_id 140712454110200. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65162920,140712454110336
# item not in cache
# Recursion wrapper received item def __init__(self, centre, intensity, effective_radius):
#     return _call_(_func_, self, centre, intensity, effective_radius)
#
# This gives item_id 140712475109136. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65162920,140712454110336
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65162920
# item not in cache
# Recursion wrapper received item effective_radius
# This gives item_id 140712454017360. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128
# item not in cache
# Recursion wrapper received item 14
# This gives item_id 10914912. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128
# item not in cache
# Recursion wrapper received item <class 'autoastro.dimensions.Length'>
# This gives item_id 65106296. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128
# item not in cache
# Recursion wrapper received item autoastro.dimensions
# This gives item_id 140712478470336. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65106296
# item not in cache
# Recursion wrapper received item <function Length.__init__ at 0x7ffa2bd5ab70>
# This gives item_id 140712453974896. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65106296
# item not in cache
# Recursion wrapper received item <property object at 0x7ffa2d1a0e08>
# This gives item_id 140712475233800. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65106296
# item not in cache
# Recursion wrapper received item <function Length.convert at 0x7ffa2bd5ac80>
# This gives item_id 140712453975168. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65106296
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,65106296
# item not in cache
# Recursion wrapper received item GaussianPrior, mean = 0.2, sigma = 0.01
# This gives item_id 140712438430016. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128
# item not in cache
# Recursion wrapper received item 15
# This gives item_id 10914944. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,140712438430016
# item not in cache
# Recursion wrapper received item 0.0
# This gives item_id 140712413054272. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,140712438430016
# item not in cache
# Recursion wrapper received item inf
# This gives item_id 140712413054296. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,140712438430016
# item not in cache
# Recursion wrapper received item 0.2
# This gives item_id 140712413054152. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,140712438430016
# item not in cache
# Recursion wrapper received item 0.01
# This gives item_id 140712413054224. Cache keys = 140713166821192,140712437989216,140712438429344,140712438429008,140712438430128,140712438430016
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192
# item not in cache
# Recursion wrapper received item None
# This gives item_id 10306432. Cache keys = 140713166821192
# item not in cache
# /home/jammy/PycharmProjects/VirtualEnvs/PyAuto/lib/python3.6/site-packages/getdist/chains.py:1022: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   weights = np.hstack((chain.weights for chain in self.chains))
# /home/jammy/PycharmProjects/VirtualEnvs/PyAuto/lib/python3.6/site-packages/getdist/chains.py:1023: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   loglikes = np.hstack((chain.loglikes for chain in self.chains))
# /home/jammy/PycharmProjects/VirtualEnvs/PyAuto/lib/python3.6/site-packages/getdist/chains.py:1024: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   self.setSamples(np.vstack((chain.samples for chain in self.chains)), weights, loglikes)
# WARNING:root:outlier fraction 0.294770206022187
# /home/jammy/PycharmProjects/PyAuto/autolens_workspace/howtolens/chapter_2_lens_modeling//output/phase_t1_non_linear_search/phase_tag__sub_2/optimizer_backup/multinest.txt
# Removed no burn in
# MultiNest has finished run - you may now continue the notebook.

# %% [markdown]
# Now this is running you should checkout the 'autolens_workspace/howtolens/chapter_2_lens_modeling/output' folder.
#
# This is where the results of the phase are written to your hard-disk (in the '1_non_linear_search' folder). When its completed, images and output will also appear in this folder, meaning that you don't need to keep running Python code to see the results.
#
# The best-fit solution (i.e. the highest likelihood) is stored in the 'results', which we can plot as per usual.

# %%
al.plot.fit_imaging.subplot(fit=results.most_likely_fit)

# %% [markdown]
# The fit looks good and we've therefore found a model close to the one I used to simulat the image with (you can confirm this yourself if you want, by comparing the inferred parameters to those found in the simulate function above).
#
# And with that, we're done - you've successfully modeled your first strong lens with PyAutoLens! Before moving onto the next tutorial, I want you to think about the following:
#
# 1) a non-linear search is often said to search a 'non-linear parameter-space' - why is the term parameter-space used?
#
# 2) Why is this parameter space 'non-linear'?
#
# 3) Initially, the non-linear search randomly guesses the values of the parameters. However, it shouldn't 'know' what reasonable values for a parameter are. For example, it doesn't know that a reasonable Einstein radius is between 0.0" and 4.0"). How does it know what are reasonable values of parameters to guess?
